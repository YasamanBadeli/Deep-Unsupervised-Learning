# %% [markdown]
# # **Fashion Editorial Classification and Recoloring**
# Deep Unsupervised Learning - Final Project
#
# Yasaman Badeli. Catalina López B. Joao Vitor Peluzo Cardoso.
#
# Professor: Ali Moridnejad.
#
# Montreal, 2025.
#
# References:
# Data
# https://www.kaggle.com/code/prites/starter-fashion-product-images-dataset-e4a4b7fb-7/notebook
# https://www.kaggle.com/code/selvasubramanians/download-images-from-url/notebook
# https://www.kaggle.com/datasets/vishalbsadanand/deepfashion-1?select=datasets
# https://github.com/yousefiparsa/apparel-masking-color-detection/tree/master/examples
# Models
# https://huggingface.co/prithivMLmods/Fashion-Product-articleType
# https://www.kaggle.com/code/vipulsharma2000/imaterialist-fashion-eda-object-detection-colors/notebook
# https://osieardi.medium.com/no-cap-just-rgb-pythons-image-color-detection-3e06218d8531

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import requests
from io import BytesIO

# %%
print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")

base_path = r"/kaggle/input/dataset-col/Deep-Unsupervised-Learning\fashion-dataset\fashion-dataset"

images_file = os.path.join(base_path, "images.csv")
styles_file = os.path.join(base_path, "styles.csv")


images_df = pd.read_csv(images_file)
styles_df = pd.read_csv(styles_file, on_bad_lines='skip')
# Out:
# 2.5.1+cu121
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
images_df['id'] = images_df['filename'].apply(lambda x: x.replace('.jpg', '')).astype(int)

df = pd.merge(images_df, styles_df, on='id')

image_download_dir = os.path.join(base_path, "downloaded_images")
os.makedirs(image_download_dir, exist_ok=True)

for idx, row in df.iterrows():
    img_id = row['id']
    img_url = row['link']
    img_path = os.path.join(image_download_dir, f"{img_id}.jpg")
    
    if not os.path.exists(img_path):
        try:
            response = requests.get(img_url, timeout=5)
            with open(img_path, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded image {img_id}")
        except Exception as e:
            print(f"Failed to download image {img_id}: {e}")
# Out:
# Downloaded image 15970
# Downloaded image 39386
# Downloaded image 59263
# Downloaded image 21379
# Downloaded image 53759
# Downloaded image 1855
# Downloaded image 30805
# Downloaded image 26960
# Downloaded image 29114
# Downloaded image 30039
# Downloaded image 9204
# Downloaded image 48123
# Downloaded image 18653
# Downloaded image 47957
# Downloaded image 46885
# Downloaded image 12369
# Downloaded image 29928
# Downloaded image 42419
# Downloaded image 51832
# Downloaded image 47359
# Downloaded image 17429
# Downloaded image 12967
# Downloaded image 6842
# Downloaded image 13089
# Downloaded image 18461
# Downloaded image 9036
# Downloaded image 48311
# Downloaded image 7990
# Downloaded image 56019
# Downloaded image 21977
# Downloaded image 37812
# Downloaded image 4729
# Downloaded image 56825
# Downloaded image 39988
# Downloaded image 59051
# Downloaded image 20099
# Downloaded image 58183
# Downloaded image 29742
# Downloaded image 51658
# Downloaded image 3954
# Downloaded image 18839
# Downloaded image 2886
# Downloaded image 23278
# Downloaded image 28690
# Downloaded image 8580
# Downloaded image 3168
# Downloaded image 18005
# Downloaded image 17871
# Downloaded image 9452
# Downloaded image 38402
# Downloaded image 44984
# Downloaded image 10268
# Downloaded image 45856
# Downloaded image 32138
# Downloaded image 59435
# Downloaded image 5891
# Downloaded image 38630
# Downloaded image 4943
# Downloaded image 11188
# Downloaded image 10866
# Downloaded image 59607
# Downloaded image 15528
# Downloaded image 45258
# Downloaded image 42841
# Downloaded image 22198
# Downloaded image 29570
# Downloaded image 43993
# Downloaded image 6628
# Downloaded image 54924
# Downloaded image 26538
# Downloaded image 35913
# Downloaded image 49495
# Downloaded image 9660
# Downloaded image 2288
# Downloaded image 23876
# Downloaded image 18237
# Downloaded image 54118
# Downloaded image 2872
# Downloaded image 49653
# Downloaded image 8574
# Downloaded image 16957
# Downloaded image 19123
# Downloaded image 13419
# Downloaded image 17885
# Downloaded image 43369
# Downloaded image 48781
# Downloaded image 44970
# Downloaded image 56489
# Downloaded image 39524
# Downloaded image 33822
# Downloaded image 58513
# Downloaded image 25947
# Downloaded image 52029
# Downloaded image 5865
# Downloaded image 39716
# Downloaded image 25349
# Downloaded image 11940
# Downloaded image 55802
# Downloaded image 29584
# Downloaded image 43967
# Downloaded image 28456
# Downloaded image 34009
# Downloaded image 19311
# Downloaded image 42089
# Downloaded image 22950
# Downloaded image 49461
# Downloaded image 8746
# Downloaded image 9694
# Downloaded image 23882
# Downloaded image 34835
# Downloaded image 15984
# Downloaded image 41268
# Downloaded image 11518
# Downloaded image 14856
# Downloaded image 33648
# Downloaded image 59297
# Downloaded image 28032
# Downloaded image 27846
# Downloaded image 26994
# Downloaded image 49839
# Downloaded image 31923
# Downloaded image 2618
# Downloaded image 54588
# Downloaded image 49005
# Downloaded image 8322
# Downloaded image 13841
# Downloaded image 28200
# Downloaded image 12993
# Downloaded image 7158
# Downloaded image 18495
# Downloaded image 8110
# Downloaded image 19547
# Downloaded image 7964
# Downloaded image 36934
# Downloaded image 39140
# Downloaded image 20851
# Downloaded image 41866
# Downloaded image 58177
# Downloaded image 44528
# Downloaded image 16392
# Downloaded image 51455
# Downloaded image 50587
# Downloaded image 17240
# Downloaded image 47530
# Downloaded image 6617
# Downloaded image 12732
# Downloaded image 3365
# Downloaded image 42042
# Downloaded image 23849
# Downloaded image 43190
# Downloaded image 48578
# Downloaded image 30462
# Downloaded image 18208
# Downloaded image 54127
# Downloaded image 10065
# Downloaded image 24250
# Downloaded image 32335
# Downloaded image 25382
# Downloaded image 56670
# Downloaded image 5092
# Downloaded image 10859
# Downloaded image 59638
# Downloaded image 15517
# Downloaded image 4140
# Downloaded image 36795
# Downloaded image 40527
# Downloaded image 10257
# Downloaded image 24062
# Downloaded image 45869
# Downloaded image 11385
# Downloaded image 53130
# Downloaded image 44187
# Downloaded image 21510
# Downloaded image 51667
# Downloaded image 22395
# Downloaded image 35322
# Downloaded image 6425
# Downloaded image 18806
# Downloaded image 23247
# Downloaded image 17072
# Downloaded image 31782
# Downloaded image 42270
# Downloaded image 12500
# Downloaded image 26735
# Downloaded image 30650
# Downloaded image 56026
# Downloaded image 21948
# Downloaded image 32563
# Downloaded image 58980
# Downloaded image 40143
# Downloaded image 10633
# Downloaded image 24406
# Downloaded image 4716
# Downloaded image 21174
# Downloaded image 15341
# Downloaded image 52486
# Downloaded image 53554
# Downloaded image 14293
# Downloaded image 47366
# Downloaded image 6041
# Downloaded image 23623
# Downloaded image 17416
# Downloaded image 9835
# Downloaded image 29319
# Downloaded image 7193
# Downloaded image 12958
# Downloaded image 27283
# Downloaded image 30234
# Downloaded image 9009
# Downloaded image 3533
# Downloaded image 42614
# Downloaded image 12164
# Downloaded image 26351
# Downloaded image 17624
# Downloaded image 47154
# Downloaded image 35574
# Downloaded image 46086
# Downloaded image 51031
# Downloaded image 13284
# Downloaded image 54543
# Downloaded image 55491
# Downloaded image 26163
# Downloaded image 3701
# Downloaded image 29917
# Downloaded image 42426
# Downloaded image 32751
# Downloaded image 56214
# Downloaded image 10401
# Downloaded image 40371
# Downloaded image 21346
# Downloaded image 45603
# Downloaded image 4524
# Downloaded image 37223
# Downloaded image 53766
# Downloaded image 25520
# Downloaded image 32597
# Downloaded image 58974
# Downloaded image 33445
# Downloaded image 57100
# Downloaded image 36137
# Downloaded image 41859
# Downloaded image 21180
# Downloaded image 39943
# Downloaded image 52472
# Downloaded image 58148
# Downloaded image 20052
# Downloaded image 5630
# Downloaded image 44517
# Downloaded image 47392
# Downloaded image 50325
# Downloaded image 8913
# Downloaded image 16530
# Downloaded image 22705
# Downloaded image 7167
# Downloaded image 46240
# Downloaded image 27277
# Downloaded image 13042
# Downloaded image 6889
# Downloaded image 31312
# Downloaded image 12190
# Downloaded image 55657
# Downloaded image 19578
# Downloaded image 27879
# Downloaded image 34452
# Downloaded image 6287
# Downloaded image 7355
# Downloaded image 46072
# Downloaded image 22537
# Downloaded image 28831
# Downloaded image 43500
# Downloaded image 2627
# Downloaded image 27045
# Downloaded image 13270
# Downloaded image 18698
# Downloaded image 55465
# Downloaded image 26197
# Downloaded image 31120
# Downloaded image 25712
# Downloaded image 11527
# Downloaded image 14869
# Downloaded image 40385
# Downloaded image 15187
# Downloaded image 5402
# Downloaded image 44725
# Downloaded image 14055
# Downloaded image 20260
# Downloaded image 7731
# Downloaded image 22153
# Downloaded image 43958
# Downloaded image 28469
# Downloaded image 50573
# Downloaded image 34036
# Downloaded image 55001
# Downloaded image 8779
# Downloaded image 3391
# Downloaded image 43164
# Downloaded image 2243
# Downloaded image 30496
# Downloaded image 27421
# Downloaded image 57756
# Downloaded image 33213
# Downloaded image 39729
# Downloaded image 25376
# Downloaded image 11143
# Downloaded image 56684
# Downloaded image 4988
# Downloaded image 44341
# Downloaded image 14431
# Downloaded image 20604
# Downloaded image 52224
# Downloaded image 45293
# Downloaded image 36761
# Downloaded image 33021
# Downloaded image 25144
# Downloaded image 11371
# Downloaded image 41401
# Downloaded image 14603
# Downloaded image 37481
# Downloaded image 5254
# Downloaded image 44173
# Downloaded image 25978
# Downloaded image 4386
# Downloaded image 51693
# Downloaded image 16154
# Downloaded image 22361
# Downloaded image 29789
# Downloaded image 19920
# Downloaded image 7503
# Downloaded image 46624
# Downloaded image 34204
# Downloaded image 17086
# Downloaded image 50741
# Downloaded image 55233
# Downloaded image 13426
# Downloaded image 43356
# Downloaded image 28207
# Downloaded image 13846
# Downloaded image 12994
# Downloaded image 46278
# Downloaded image 16508
# Downloaded image 18492
# Downloaded image 19540
# Downloaded image 7963
# Downloaded image 8117
# Downloaded image 49230
# Downloaded image 39147
# Downloaded image 36933
# Downloaded image 57138
# Downloaded image 20856
# Downloaded image 41861
# Downloaded image 5608
# Downloaded image 58170
# Downloaded image 53598
# Downloaded image 15983
# Downloaded image 39375
# Downloaded image 14851
# Downloaded image 59290
# Downloaded image 52678
# Downloaded image 20258
# Downloaded image 47198
# Downloaded image 27841
# Downloaded image 28035
# Downloaded image 31924
# Downloaded image 26993
# Downloaded image 13248
# Downloaded image 43538
# Downloaded image 8325
# Downloaded image 31118
# Downloaded image 19772
# Downloaded image 46876
# Downloaded image 5862
# Downloaded image 39711
# Downloaded image 14409
# Downloaded image 58726
# Downloaded image 44379
# Downloaded image 11947
# Downloaded image 36759
# Downloaded image 51499
# Downloaded image 29583
# Downloaded image 55805
# Downloaded image 7709
# Downloaded image 28451
# Downloaded image 43960
# Downloaded image 8741
# Downloaded image 55039
# Downloaded image 19316
# Downloaded image 27419
# Downloaded image 34832
# Downloaded image 23885
# Downloaded image 19918
# Downloaded image 22359
# Downloaded image 19124
# Downloaded image 16950
# Downloaded image 49654
# Downloaded image 48786
# Downloaded image 2049
# Downloaded image 17882
# Downloaded image 44977
# Downloaded image 33019
# Downloaded image 41439
# Downloaded image 39523
# Downloaded image 52812
# Downloaded image 11349
# Downloaded image 24892
# Downloaded image 58514
# Downloaded image 33825
# Downloaded image 25940
# Downloaded image 38637
# Downloaded image 5896
# Downloaded image 4944
# Downloaded image 10861
# Downloaded image 59600
# Downloaded image 42846
# Downloaded image 35128
# Downloaded image 47508
# Downloaded image 54923
# Downloaded image 43994
# Downloaded image 17278
# Downloaded image 31588
# Downloaded image 49492
# Downloaded image 18230
# Downloaded image 23871
# Downloaded image 9667
# Downloaded image 16198
# Downloaded image 3953
# Downloaded image 29745
# Downloaded image 28697
# Downloaded image 12538
# Downloaded image 8587
# Downloaded image 42248
# Downloaded image 48772
# Downloaded image 17876
# Downloaded image 30668
# Downloaded image 9455
# Downloaded image 18002
# Downloaded image 44983
# Downloaded image 38405
# Downloaded image 53934
# Downloaded image 1638
# Downloaded image 25188
# Downloaded image 24866
# Downloaded image 53108
# Downloaded image 21528
# Downloaded image 59432
# Downloaded image 32903
# Downloaded image 6079
# Downloaded image 12960
# Downloaded image 29321
# Downloaded image 9031
# Downloaded image 6845
# Downloaded image 18466
# Downloaded image 26369
# Downloaded image 33489
# Downloaded image 59056
# Downloaded image 15379
# Downloaded image 45409
# Downloaded image 56822
# Downloaded image 58184
# Downloaded image 40947
# Downloaded image 39381
# Downloaded image 15977
# Downloaded image 32769
# Downloaded image 10439
# Downloaded image 59264
# Downloaded image 14099
# Downloaded image 1852
# Downloaded image 30802
# Downloaded image 51009
# Downloaded image 29113
# Downloaded image 7399
# Downloaded image 26967
# Downloaded image 27089
# Downloaded image 48124
# Downloaded image 9203
# Downloaded image 51835
# Downloaded image 3739
# Downloaded image 19786
# Downloaded image 44948
# Downloaded image 24091
# Downloaded image 57563
# Downloaded image 33026
# Downloaded image 41406
# Downloaded image 11376
# Downloaded image 25143
# Downloaded image 44174
# Downloaded image 5253
# Downloaded image 20431
# Downloaded image 14604
# Downloaded image 4381
# Downloaded image 46623
# Downloaded image 19927
# Downloaded image 7504
# Downloaded image 22366
# Downloaded image 3998
# Downloaded image 51694
# Downloaded image 16153
# Downloaded image 17081
# Downloaded image 50746
# Downloaded image 34203
# Downloaded image 55234
# Downloaded image 13421
# Downloaded image 27614
# Downloaded image 22154
# Downloaded image 16361
# Downloaded image 46411
# Downloaded image 7736
# Downloaded image 34031
# Downloaded image 50574
# Downloaded image 22968
# Downloaded image 3396
# Downloaded image 31543
# Downloaded image 55006
# Downloaded image 19329
# Downloaded image 13613
# Downloaded image 27426
# Downloaded image 2244
# Downloaded image 43163
# Downloaded image 33214
# Downloaded image 10096
# Downloaded image 11144
# Downloaded image 25371
# Downloaded image 20603
# Downloaded image 58719
# Downloaded image 11978
# Downloaded image 36766
# Downloaded image 45294
# Downloaded image 52223
# Downloaded image 34455
# Downloaded image 6280
# Downloaded image 46075
# Downloaded image 35587
# Downloaded image 7352
# Downloaded image 27042
# Downloaded image 2620
# Downloaded image 43507
# Downloaded image 28836
# Downloaded image 31127
# Downloaded image 26190
# Downloaded image 55462
# Downloaded image 11520
# Downloaded image 25715
# Downloaded image 41250
# Downloaded image 40382
# Downloaded image 38298
# Downloaded image 57335
# Downloaded image 52647
# Downloaded image 20267
# Downloaded image 14052
# Downloaded image 53795
# Downloaded image 44722
# Downloaded image 5405
# Downloaded image 39178
# Downloaded image 32590
# Downloaded image 11712
# Downloaded image 25527
# Downloaded image 57107
# Downloaded image 20869
# Downloaded image 33442
# Downloaded image 58973
# Downloaded image 52475
# Downloaded image 39944
# Downloaded image 21187
# Downloaded image 36130
# Downloaded image 44510
# Downloaded image 20055
# Downloaded image 50322
# Downloaded image 28238
# Downloaded image 13879
# Downloaded image 47395
# Downloaded image 46247
# Downloaded image 7160
# Downloaded image 22702
# Downloaded image 8914
# Downloaded image 16537
# Downloaded image 43735
# Downloaded image 13045
# Downloaded image 27270
# Downloaded image 12197
# Downloaded image 55650
# Downloaded image 31315
# Downloaded image 6274
# Downloaded image 47153
# Downloaded image 17623
# Downloaded image 48927
# Downloaded image 51036
# Downloaded image 26958
# Downloaded image 46081
# Downloaded image 35573
# Downloaded image 13283
# Downloaded image 54544
# Downloaded image 30001
# Downloaded image 29910
# Downloaded image 3706
# Downloaded image 26164
# Downloaded image 55496
# Downloaded image 56213
# Downloaded image 15948
# Downloaded image 40376
# Downloaded image 24633
# Downloaded image 10406
# Downloaded image 4523
# Downloaded image 45604
# Downloaded image 15174
# Downloaded image 21341
# Downloaded image 53761
# Downloaded image 37224
# Downloaded image 32564
# Downloaded image 56021
# Downloaded image 24401
# Downloaded image 10634
# Downloaded image 40144
# Downloaded image 58987
# Downloaded image 59069
# Downloaded image 15346
# Downloaded image 52481
# Downloaded image 21173
# Downloaded image 4711
# Downloaded image 40978
# Downloaded image 14294
# Downloaded image 17411
# Downloaded image 9832
# Downloaded image 23624
# Downloaded image 6046
# Downloaded image 34693
# Downloaded image 47361
# Downloaded image 7194
# Downloaded image 51204
# Downloaded image 30233
# Downloaded image 48329
# Downloaded image 18459
# Downloaded image 27284
# Downloaded image 12163
# Downloaded image 42613
# Downloaded image 3534
# Downloaded image 24065
# Downloaded image 10250
# Downloaded image 57597
# Downloaded image 40520
# Downloaded image 1607
# Downloaded image 11382
# Downloaded image 44180
# Downloaded image 37472
# Downloaded image 53137
# Downloaded image 15722
# Downloaded image 4375
# Downloaded image 35325
# Downloaded image 22392
# Downloaded image 51660
# Downloaded image 17075
# Downloaded image 23240
# Downloaded image 6422
# Downloaded image 18801
# Downloaded image 26732
# Downloaded image 12507
# Downloaded image 31785
# Downloaded image 3150
# Downloaded image 17849
# Downloaded image 29548
# Downloaded image 42879
# Downloaded image 16395
# Downloaded image 51452
# Downloaded image 6610
# Downloaded image 47537
# Downloaded image 17247
# Downloaded image 23072
# Downloaded image 42045
# Downloaded image 3362
# Downloaded image 12735
# Downloaded image 54120
# Downloaded image 30465
# Downloaded image 9658
# Downloaded image 43197
# Downloaded image 38608
# Downloaded image 24257
# Downloaded image 10062
# Downloaded image 56677
# Downloaded image 25385
# Downloaded image 32332
# Downloaded image 5095
# Downloaded image 37640
# Downloaded image 4147
# Downloaded image 36792
# Downloaded image 45260
# Downloaded image 15510
# Downloaded image 21725
# Downloaded image 34038
# Downloaded image 43956
# Downloaded image 28467
# Downloaded image 16368
# Downloaded image 42884
# Downloaded image 55833
# Downloaded image 46418
# Downloaded image 48582
# Downloaded image 30498
# Downloaded image 8777
# Downloaded image 19320
# Downloaded image 25378
# Downloaded image 4986
# Downloaded image 39727
# Downloaded image 57758
# Downloaded image 5854
# Downloaded image 11971
# Downloaded image 5068
# Downloaded image 39515
# Downloaded image 45893
# Downloaded image 44941
# Downloaded image 24098
# Downloaded image 4388
# Downloaded image 58522
# Downloaded image 28655
# Downloaded image 2843
# Downloaded image 17088
# Downloaded image 3991
# Downloaded image 29787
# Downloaded image 9497
# Downloaded image 13428
# Downloaded image 19112
# Downloaded image 16966
# Downloaded image 49662
# Downloaded image 20860
# Downloaded image 32599
# Downloaded image 39171
# Downloaded image 36905
# Downloaded image 57932
# Downloaded image 58146
# Downloaded image 40985
# Downloaded image 41857
# Downloaded image 59094
# Downloaded image 36139
# Downloaded image 7169
# Downloaded image 28231
# Downloaded image 13870
# Downloaded image 19576
# Downloaded image 7955
# Downloaded image 8121
# Downloaded image 27279
# Downloaded image 6887
# Downloaded image 31912
# Downloaded image 49808
# Downloaded image 22539
# Downloaded image 27877
# Downloaded image 6289
# Downloaded image 28003
# Downloaded image 8313
# Downloaded image 49034
# Downloaded image 19744
# Downloaded image 26199
# Downloaded image 47992
# Downloaded image 18696
# Downloaded image 2629
# Downloaded image 14867
# Downloaded image 38291
# Downloaded image 11529
# Downloaded image 41259
# Downloaded image 1890
# Downloaded image 15189
# Downloaded image 24408
# Downloaded image 20894
# Downloaded image 21946
# Downloaded image 39185
# Downloaded image 56028
# Downloaded image 40971
# Downloaded image 52488
# Downloaded image 59060
# Downloaded image 4718
# Downloaded image 56814
# Downloaded image 12956
# Downloaded image 29317
# Downloaded image 17418
# Downloaded image 47368
# Downloaded image 13884
# Downloaded image 19582
# Downloaded image 48320
# Downloaded image 9007
# Downloaded image 6873
# Downloaded image 18450
# Downloaded image 29125
# Downloaded image 26951
# Downloaded image 27883
# Downloaded image 30834
# Downloaded image 29919
# Downloaded image 42428
# Downloaded image 12358
# Downloaded image 48112
# Downloaded image 9235
# Downloaded image 14893
# Downloaded image 15941
# Downloaded image 53768
# Downloaded image 21348
# Downloaded image 59252
# Downloaded image 6619
# Downloaded image 54915
# Downloaded image 50589
# Downloaded image 42870
# Downloaded image 18206
# Downloaded image 54129
# Downloaded image 23847
# Downloaded image 48576
# Downloaded image 9651
# Downloaded image 8783
# Downloaded image 4972
# Downloaded image 38601
# Downloaded image 45269
# Downloaded image 11985
# Downloaded image 59636
# Downloaded image 15519
# Downloaded image 10857
# Downloaded image 10259
# Downloaded image 53902
# Downloaded image 38433
# Downloaded image 40529
# Downloaded image 59404
# Downloaded image 25982
# Downloaded image 44189
# Downloaded image 24850
# Downloaded image 23249
# Downloaded image 18808
# Downloaded image 51669
# Downloaded image 3965
# Downloaded image 29773
# Downloaded image 48744
# Downloaded image 17840
# Downloaded image 9463
# Downloaded image 18034
# Downloaded image 16992
# Downloaded image 3159
# Downloaded image 49696
# Downloaded image 14858
# Downloaded image 33646
# Downloaded image 57303
# Downloaded image 11516
# Downloaded image 41266
# Downloaded image 20251
# Downloaded image 14064
# Downloaded image 44714
# Downloaded image 5433
# Downloaded image 52671
# Downloaded image 59299
# Downloaded image 49837
# Downloaded image 16733
# Downloaded image 7364
# Downloaded image 34463
# Downloaded image 47191
# Downloaded image 27848
# Downloaded image 31111
# Downloaded image 55454
# Downloaded image 12393
# Downloaded image 13241
# Downloaded image 54586
# Downloaded image 27074
# Downloaded image 2616
# Downloaded image 43531
# Downloaded image 46271
# Downloaded image 35783
# Downloaded image 7156
# Downloaded image 22734
# Downloaded image 8922
# Downloaded image 16501
# Downloaded image 50314
# Downloaded image 34651
# Downloaded image 6084
# Downloaded image 19549
# Downloaded image 49239
# Downloaded image 31323
# Downloaded image 43703
# Downloaded image 13073
# Downloaded image 57131
# Downloaded image 40186
# Downloaded image 58945
# Downloaded image 33474
# Downloaded image 59897
# Downloaded image 11724
# Downloaded image 5601
# Downloaded image 20063
# Downloaded image 53591
# Downloaded image 58179
# Downloaded image 39972
# Downloaded image 15384
# Downloaded image 52443
# Downloaded image 41868
# Downloaded image 36106
# Downloaded image 23282
# Downloaded image 34235
# Downloaded image 46615
# Downloaded image 19911
# Downloaded image 7532
# Downloaded image 22350
# Downloaded image 16165
# Downloaded image 2040
# Downloaded image 30695
# Downloaded image 43367
# Downloaded image 13417
# Downloaded image 27622
# Downloaded image 55202
# Downloaded image 3192
# Downloaded image 16959
# Downloaded image 11340
# Downloaded image 25175
# Downloaded image 10292
# Downloaded image 57555
# Downloaded image 52027
# Downloaded image 36562
# Downloaded image 25949
# Downloaded image 44142
# Downloaded image 5265
# Downloaded image 14632
# Downloaded image 11172
# Downloaded image 25347
# Downloaded image 39718
# Downloaded image 41602
# Downloaded image 33222
# Downloaded image 24295
# Downloaded image 57767
# Downloaded image 36750
# Downloaded image 37682
# Downloaded image 34007
# Downloaded image 50542
# Downloaded image 17285
# Downloaded image 43969
# Downloaded image 28458
# Downloaded image 22162
# Downloaded image 16357
# Downloaded image 46427
# Downloaded image 7700
# Downloaded image 27410
# Downloaded image 2272
# Downloaded image 43155
# Downloaded image 42087
# Downloaded image 8748
# Downloaded image 55030
# Downloaded image 17043
# Downloaded image 50784
# Downloaded image 2888
# Downloaded image 23276
# Downloaded image 6414
# Downloaded image 18837
# Downloaded image 35313
# Downloaded image 51656
# Downloaded image 16191
# Downloaded image 30661
# Downloaded image 43393
# Downloaded image 26704
# Downloaded image 12531
# Downloaded image 42241
# Downloaded image 56473
# Downloaded image 25181
# Downloaded image 24053
# Downloaded image 10266
# Downloaded image 40516
# Downloaded image 15714
# Downloaded image 21521
# Downloaded image 4343
# Downloaded image 5291
# Downloaded image 53101
# Downloaded image 32304
# Downloaded image 57793
# Downloaded image 10054
# Downloaded image 4171
# Downloaded image 45256
# Downloaded image 59609
# Downloaded image 15526
# Downloaded image 21713
# Downloaded image 44384
# Downloaded image 37676
# Downloaded image 6626
# Downloaded image 47501
# Downloaded image 17271
# Downloaded image 23044
# Downloaded image 22196
# Downloaded image 51464
# Downloaded image 54116
# Downloaded image 30453
# Downloaded image 2286
# Downloaded image 23878
# Downloaded image 48549
# Downloaded image 42073
# Downloaded image 31581
# Downloaded image 3354
# Downloaded image 26536
# Downloaded image 12703
# Downloaded image 24605
# Downloaded image 10430
# Downloaded image 56225
# Downloaded image 39388
# Downloaded image 14090
# Downloaded image 53757
# Downloaded image 37212
# Downloaded image 4515
# Downloaded image 45632
# Downloaded image 51000
# Downloaded image 7390
# Downloaded image 35545
# Downloaded image 6242
# Downloaded image 47165
# Downloaded image 17615
# Downloaded image 48911
# Downloaded image 29926
# Downloaded image 42417
# Downloaded image 3730
# Downloaded image 26152
# Downloaded image 12367
# Downloaded image 54572
# Downloaded image 27080
# Downloaded image 30037
# Downloaded image 46285
# Downloaded image 12969
# Downloaded image 35777
# Downloaded image 51232
# Downloaded image 17427
# Downloaded image 9804
# Downloaded image 23612
# Downloaded image 6070
# Downloaded image 47357
# Downloaded image 26360
# Downloaded image 12155
# Downloaded image 42625
# Downloaded image 3502
# Downloaded image 30205
# Downloaded image 9038
# Downloaded image 54740
# Downloaded image 13087
# Downloaded image 10602
# Downloaded image 40172
# Downloaded image 33480
# Downloaded image 59863
# Downloaded image 32552
# Downloaded image 21979
# Downloaded image 56017
# Downloaded image 20097
# Downloaded image 53565
# Downloaded image 15370
# Downloaded image 39986
# Downloaded image 21145
# Downloaded image 4727
# Downloaded image 45400
# Downloaded image 38434
# Downloaded image 53905
# Downloaded image 1609
# Downloaded image 57599
# Downloaded image 25985
# Downloaded image 59403
# Downloaded image 21519
# Downloaded image 53139
# Downloaded image 29774
# Downloaded image 3962
# Downloaded image 18033
# Downloaded image 17847
# Downloaded image 9464
# Downloaded image 48743
# Downloaded image 16995
# Downloaded image 12509
# Downloaded image 17249
# Downloaded image 47539
# Downloaded image 29546
# Downloaded image 42877
# Downloaded image 9656
# Downloaded image 23840
# Downloaded image 43199
# Downloaded image 18201
# Downloaded image 35925
# Downloaded image 8784
# Downloaded image 4975
# Downloaded image 56679
# Downloaded image 24259
# Downloaded image 38606
# Downloaded image 59631
# Downloaded image 4149
# Downloaded image 10850
# Downloaded image 26956
# Downloaded image 29122
# Downloaded image 51038
# Downloaded image 30833
# Downloaded image 48929
# Downloaded image 27884
# Downloaded image 55498
# Downloaded image 3708
# Downloaded image 48115
# Downloaded image 18665
# Downloaded image 47961
# Downloaded image 10408
# Downloaded image 14894
# Downloaded image 15946
# Downloaded image 1863
# Downloaded image 59255
# Downloaded image 20893
# Downloaded image 58989
# Downloaded image 38050
# Downloaded image 39182
# Downloaded image 41098
# Downloaded image 21941
# Downloaded image 56813
# Downloaded image 59067
# Downloaded image 15348
# Downloaded image 12951
# Downloaded image 6048
# Downloaded image 13883
# Downloaded image 19585
# Downloaded image 6874
# Downloaded image 18457
# Downloaded image 9000
# Downloaded image 48327
# Downloaded image 35589
# Downloaded image 31915
# Downloaded image 28004
# Downloaded image 27870
# Downloaded image 19743
# Downloaded image 49033
# Downloaded image 8314
# Downloaded image 31129
# Downloaded image 43509
# Downloaded image 18691
# Downloaded image 47995
# Downloaded image 38296
# Downloaded image 14860
# Downloaded image 39344
# Downloaded image 1897
# Downloaded image 52649
# Downloaded image 57109
# Downloaded image 36902
# Downloaded image 25529
# Downloaded image 39176
# Downloaded image 40982
# Downloaded image 58141
# Downloaded image 57935
# Downloaded image 59093
# Downloaded image 41850
# Downloaded image 21189
# Downloaded image 16539
# Downloaded image 46249
# Downloaded image 13877
# Downloaded image 28236
# Downloaded image 8126
# Downloaded image 19571
# Downloaded image 12199
# Downloaded image 7952
# Downloaded image 6880
# Downloaded image 11378
# Downloaded image 45894
# Downloaded image 39512
# Downloaded image 52823
# Downloaded image 41408
# Downloaded image 33028
# Downloaded image 25971
# Downloaded image 58525
# Downloaded image 37488
# Downloaded image 2844
# Downloaded image 50748
# Downloaded image 28652
# Downloaded image 29780
# Downloaded image 22368
# Downloaded image 3996
# Downloaded image 19929
# Downloaded image 2078
# Downloaded image 9490
# Downloaded image 49665
# Downloaded image 8542
# Downloaded image 16961
# Downloaded image 19115
# Downloaded image 28460
# Downloaded image 23088
# Downloaded image 43951
# Downloaded image 55834
# Downloaded image 42883
# Downloaded image 48585
# Downloaded image 34803
# Downloaded image 27428
# Downloaded image 55008
# Downloaded image 19327
# Downloaded image 3398
# Downloaded image 39720
# Downloaded image 10098
# Downloaded image 5853
# Downloaded image 11976
# Downloaded image 36768
# Downloaded image 44348
# Downloaded image 14438
# Downloaded image 46282
# Downloaded image 47350
# Downloaded image 23615
# Downloaded image 17420
# Downloaded image 9803
# Downloaded image 3505
# Downloaded image 42622
# Downloaded image 12152
# Downloaded image 26367
# Downloaded image 18468
# Downloaded image 13080
# Downloaded image 48318
# Downloaded image 30202
# Downloaded image 33487
# Downloaded image 40175
# Downloaded image 10605
# Downloaded image 56010
# Downloaded image 32555
# Downloaded image 53562
# Downloaded image 40949
# Downloaded image 45407
# Downloaded image 4720
# Downloaded image 21142
# Downloaded image 39981
# Downloaded image 59058
# Downloaded image 15377
# Downloaded image 10437
# Downloaded image 24602
# Downloaded image 32767
# Downloaded image 56222
# Downloaded image 37215
# Downloaded image 14097
# Downloaded image 53750
# Downloaded image 52682
# Downloaded image 15145
# Downloaded image 45635
# Downloaded image 4512
# Downloaded image 7397
# Downloaded image 35542
# Downloaded image 26969
# Downloaded image 51007
# Downloaded image 48916
# Downloaded image 17612
# Downloaded image 47162
# Downloaded image 6245
# Downloaded image 19788
# Downloaded image 12360
# Downloaded image 26155
# Downloaded image 3737
# Downloaded image 42410
# Downloaded image 29921
# Downloaded image 27087
# Downloaded image 54575
# Downloaded image 32303
# Downloaded image 56646
# Downloaded image 5898
# Downloaded image 57794
# Downloaded image 10053
# Downloaded image 24266
# Downloaded image 38639
# Downloaded image 15521
# Downloaded image 45251
# Downloaded image 37671
# Downloaded image 44383
# Downloaded image 23043
# Downloaded image 17276
# Downloaded image 47506
# Downloaded image 6621
# Downloaded image 51463
# Downloaded image 42848
# Downloaded image 22191
# Downloaded image 9669
# Downloaded image 54111
# Downloaded image 12704
# Downloaded image 26531
# Downloaded image 31586
# Downloaded image 3353
# Downloaded image 42074
# Downloaded image 47734
# Downloaded image 6413
# Downloaded image 18830
# Downloaded image 28699
# Downloaded image 23271
# Downloaded image 17044
# Downloaded image 50783
# Downloaded image 51651
# Downloaded image 16196
# Downloaded image 35314
# Downloaded image 43394
# Downloaded image 17878
# Downloaded image 30666
# Downloaded image 3161
# Downloaded image 8589
# Downloaded image 12536
# Downloaded image 26703
# Downloaded image 25186
# Downloaded image 56474
# Downloaded image 1636
# Downloaded image 40511
# Downloaded image 10261
# Downloaded image 24054
# Downloaded image 4344
# Downloaded image 21526
# Downloaded image 15713
# Downloaded image 53106
# Downloaded image 5296
# Downloaded image 24868
# Downloaded image 41605
# Downloaded image 25340
# Downloaded image 11175
# Downloaded image 57760
# Downloaded image 24292
# Downloaded image 33225
# Downloaded image 11949
# Downloaded image 36757
# Downloaded image 37685
# Downloaded image 5050
# Downloaded image 44377
# Downloaded image 58728
# Downloaded image 50545
# Downloaded image 17282
# Downloaded image 34000
# Downloaded image 7707
# Downloaded image 46420
# Downloaded image 16350
# Downloaded image 51497
# Downloaded image 22165
# Downloaded image 43152
# Downloaded image 2275
# Downloaded image 27417
# Downloaded image 55037
# Downloaded image 19318
# Downloaded image 49468
# Downloaded image 42080
# Downloaded image 22959
# Downloaded image 34232
# Downloaded image 23285
# Downloaded image 50777
# Downloaded image 16162
# Downloaded image 22357
# Downloaded image 19916
# Downloaded image 7535
# Downloaded image 46612
# Downloaded image 27625
# Downloaded image 13410
# Downloaded image 48788
# Downloaded image 43360
# Downloaded image 2047
# Downloaded image 30692
# Downloaded image 55205
# Downloaded image 25172
# Downloaded image 56480
# Downloaded image 11347
# Downloaded image 41437
# Downloaded image 33017
# Downloaded image 10295
# Downloaded image 57552
# Downloaded image 44979
# Downloaded image 45097
# Downloaded image 36565
# Downloaded image 14635
# Downloaded image 5262
# Downloaded image 8925
# Downloaded image 16506
# Downloaded image 22733
# Downloaded image 35784
# Downloaded image 7151
# Downloaded image 46276
# Downloaded image 13848
# Downloaded image 6083
# Downloaded image 28209
# Downloaded image 50313
# Downloaded image 8119
# Downloaded image 31324
# Downloaded image 13074
# Downloaded image 43704
# Downloaded image 33473
# Downloaded image 58942
# Downloaded image 20858
# Downloaded image 40181
# Downloaded image 57136
# Downloaded image 25516
# Downloaded image 39149
# Downloaded image 59890
# Downloaded image 53596
# Downloaded image 20064
# Downloaded image 5606
# Downloaded image 44521
# Downloaded image 36101
# Downloaded image 52444
# Downloaded image 39975
# Downloaded image 57304
# Downloaded image 33641
# Downloaded image 41261
# Downloaded image 25724
# Downloaded image 11511
# Downloaded image 5434
# Downloaded image 44713
# Downloaded image 14063
# Downloaded image 20256
# Downloaded image 52676
# Downloaded image 36333
# Downloaded image 7363
# Downloaded image 46044
# Downloaded image 16734
# Downloaded image 22501
# Downloaded image 49830
# Downloaded image 47196
# Downloaded image 34464
# Downloaded image 12394
# Downloaded image 46878
# Downloaded image 31116
# Downloaded image 43536
# Downloaded image 28807
# Downloaded image 2611
# Downloaded image 13246
# Downloaded image 54581
# Downloaded image 3763
# Downloaded image 29975
# Downloaded image 26101
# Downloaded image 54521
# Downloaded image 9259
# Downloaded image 30064
# Downloaded image 16794
# Downloaded image 51053
# Downloaded image 49890
# Downloaded image 47136
# Downloaded image 6211
# Downloaded image 48942
# Downloaded image 23473
# Downloaded image 50181
# Downloaded image 17646
# Downloaded image 30858
# Downloaded image 1808
# Downloaded image 37241
# Downloaded image 5494
# Downloaded image 45661
# Downloaded image 36393
# Downloaded image 4546
# Downloaded image 21324
# Downloaded image 15111
# Downloaded image 38209
# Downloaded image 40313
# Downloaded image 10463
# Downloaded image 24656
# Downloaded image 25784
# Downloaded image 56276
# Downloaded image 37073
# Downloaded image 44581
# Downloaded image 53536
# Downloaded image 21116
# Downloaded image 15323
# Downloaded image 56878
# Downloaded image 4774
# Downloaded image 57196
# Downloaded image 40121
# Downloaded image 32501
# Downloaded image 56044
# Downloaded image 11783
# Downloaded image 12106
# Downloaded image 26333
# Downloaded image 3551
# Downloaded image 42676
# Downloaded image 2483
# Downloaded image 30256
# Downloaded image 54713
# Downloaded image 51261
# Downloaded image 9857
# Downloaded image 47304
# Downloaded image 6023
# Downloaded image 21572
# Downloaded image 15747
# Downloaded image 32959
# Downloaded image 52080
# Downloaded image 59468
# Downloaded image 45037
# Downloaded image 4310
# Downloaded image 37417
# Downloaded image 53152
# Downloaded image 14695
# Downloaded image 32165
# Downloaded image 56420
# Downloaded image 10235
# Downloaded image 1662
# Downloaded image 40545
# Downloaded image 48728
# Downloaded image 30632
# Downloaded image 27685
# Downloaded image 18058
# Downloaded image 3135
# Downloaded image 42212
# Downloaded image 23225
# Downloaded image 17010
# Downloaded image 18864
# Downloaded image 34292
# Downloaded image 6447
# Downloaded image 7595
# Downloaded image 3909
# Downloaded image 51605
# Downloaded image 13682
# Downloaded image 54145
# Downloaded image 3307
# Downloaded image 42020
# Downloaded image 55097
# Downloaded image 12750
# Downloaded image 47552
# Downloaded image 54979
# Downloaded image 6675
# Downloaded image 17222
# Downloaded image 51437
# Downloaded image 35172
# Downloaded image 46480
# Downloaded image 45205
# Downloaded image 4122
# Downloaded image 21740
# Downloaded image 15575
# Downloaded image 53360
# Downloaded image 37625
# Downloaded image 56612
# Downloaded image 32357
# Downloaded image 33285
# Downloaded image 40777
# Downloaded image 10007
# Downloaded image 21586
# Downloaded image 52074
# Downloaded image 14661
# Downloaded image 20454
# Downloaded image 32191
# Downloaded image 52848
# Downloaded image 39579
# Downloaded image 25126
# Downloaded image 57506
# Downloaded image 33043
# Downloaded image 43334
# Downloaded image 27671
# Downloaded image 54383
# Downloaded image 13444
# Downloaded image 55251
# Downloaded image 31714
# Downloaded image 8529
# Downloaded image 28639
# Downloaded image 50723
# Downloaded image 47794
# Downloaded image 34266
# Downloaded image 18890
# Downloaded image 7561
# Downloaded image 19942
# Downloaded image 46646
# Downloaded image 16136
# Downloaded image 27443
# Downloaded image 13676
# Downloaded image 43106
# Downloaded image 2221
# Downloaded image 55063
# Downloaded image 26591
# Downloaded image 6681
# Downloaded image 34054
# Downloaded image 22131
# Downloaded image 7753
# Downloaded image 35186
# Downloaded image 46474
# Downloaded image 36703
# Downloaded image 15581
# Downloaded image 14453
# Downloaded image 53394
# Downloaded image 20666
# Downloaded image 5004
# Downloaded image 25314
# Downloaded image 11121
# Downloaded image 33271
# Downloaded image 40783
# Downloaded image 5838
# Downloaded image 57734
# Downloaded image 31142
# Downloaded image 3797
# Downloaded image 29981
# Downloaded image 19728
# Downloaded image 55407
# Downloaded image 27027
# Downloaded image 13212
# Downloaded image 28853
# Downloaded image 43562
# Downloaded image 50949
# Downloaded image 30090
# Downloaded image 2645
# Downloaded image 16760
# Downloaded image 49864
# Downloaded image 22555
# Downloaded image 46010
# Downloaded image 34430
# Downloaded image 23487
# Downloaded image 50175
# Downloaded image 58318
# Downloaded image 14037
# Downloaded image 20202
# Downloaded image 5460
# Downloaded image 44747
# Downloaded image 36367
# Downloaded image 52622
# Downloaded image 57350
# Downloaded image 10497
# Downloaded image 25770
# Downloaded image 11545
# Downloaded image 56282
# Downloaded image 37087
# Downloaded image 20030
# Downloaded image 39921
# Downloaded image 52410
# Downloaded image 4780
# Downloaded image 57162
# Downloaded image 58916
# Downloaded image 33427
# Downloaded image 41007
# Downloaded image 25542
# Downloaded image 11777
# Downloaded image 7939
# Downloaded image 55635
# Downloaded image 42682
# Downloaded image 2477
# Downloaded image 27215
# Downloaded image 7105
# Downloaded image 16552
# Downloaded image 8971
# Downloaded image 22767
# Downloaded image 50347
# Downloaded image 34602
# Downloaded image 59665
# Downloaded image 14498
# Downloaded image 10804
# Downloaded image 4921
# Downloaded image 32368
# Downloaded image 39780
# Downloaded image 40748
# Downloaded image 38652
# Downloaded image 18255
# Downloaded image 27488
# Downloaded image 9602
# Downloaded image 23814
# Downloaded image 48525
# Downloaded image 3338
# Downloaded image 35971
# Downloaded image 19387
# Downloaded image 54946
# Downloaded image 23028
# Downloaded image 42823
# Downloaded image 51408
# Downloaded image 55894
# Downloaded image 7798
# Downloaded image 9430
# Downloaded image 17813
# Downloaded image 48717
# Downloaded image 6478
# Downloaded image 19989
# Downloaded image 3936
# Downloaded image 15778
# Downloaded image 59457
# Downloaded image 45008
# Downloaded image 37428
# Downloaded image 52883
# Downloaded image 45834
# Downloaded image 33088
# Downloaded image 38460
# Downloaded image 12139
# Downloaded image 42649
# Downloaded image 8186
# Downloaded image 9054
# Downloaded image 30269
# Downloaded image 48373
# Downloaded image 18403
# Downloaded image 6820
# Downloaded image 12905
# Downloaded image 9868
# Downloaded image 28296
# Downloaded image 57995
# Downloaded image 5699
# Downloaded image 40922
# Downloaded image 38838
# Downloaded image 59033
# Downloaded image 21129
# Downloaded image 56847
# Downloaded image 37870
# Downloaded image 38004
# Downloaded image 21915
# Downloaded image 25589
# Downloaded image 4579
# Downloaded image 38236
# Downloaded image 24669
# Downloaded image 56249
# Downloaded image 15912
# Downloaded image 49093
# Downloaded image 31189
# Downloaded image 18631
# Downloaded image 9266
# Downloaded image 50982
# Downloaded image 28898
# Downloaded image 48141
# Downloaded image 29176
# Downloaded image 26902
# Downloaded image 35529
# Downloaded image 47109
# Downloaded image 17679
# Downloaded image 30867
# Downloaded image 7906
# Downloaded image 19525
# Downloaded image 8172
# Downloaded image 48387
# Downloaded image 22758
# Downloaded image 50378
# Downloaded image 28262
# Downloaded image 57961
# Downloaded image 58115
# Downloaded image 37884
# Downloaded image 20833
# Downloaded image 39122
# Downloaded image 41038
# Downloaded image 58327
# Downloaded image 14008
# Downloaded image 44778
# Downloaded image 36358
# Downloaded image 14834
# Downloaded image 39310
# Downloaded image 49067
# Downloaded image 8340
# Downloaded image 46813
# Downloaded image 19717
# Downloaded image 55438
# Downloaded image 27018
# Downloaded image 50976
# Downloaded image 29182
# Downloaded image 31941
# Downloaded image 7308
# Downloaded image 30893
# Downloaded image 28050
# Downloaded image 48989
# Downloaded image 11922
# Downloaded image 59691
# Downloaded image 58743
# Downloaded image 5807
# Downloaded image 13649
# Downloaded image 34857
# Downloaded image 22932
# Downloaded image 8724
# Downloaded image 35985
# Downloaded image 47599
# Downloaded image 28434
# Downloaded image 55860
# Downloaded image 19141
# Downloaded image 49631
# Downloaded image 8516
# Downloaded image 28606
# Downloaded image 34259
# Downloaded image 46679
# Downloaded image 16109
# Downloaded image 25925
# Downloaded image 5209
# Downloaded image 33840
# Downloaded image 58571
# Downloaded image 52877
# Downloaded image 39546
# Downloaded image 25119
# Downloaded image 44912
# Downloaded image 57539
# Downloaded image 38494
# Downloaded image 20037
# Downloaded image 44572
# Downloaded image 37080
# Downloaded image 57959
# Downloaded image 4787
# Downloaded image 52417
# Downloaded image 39926
# Downloaded image 58911
# Downloaded image 24497
# Downloaded image 57165
# Downloaded image 11770
# Downloaded image 41000
# Downloaded image 42685
# Downloaded image 55632
# Downloaded image 13027
# Downloaded image 27212
# Downloaded image 43757
# Downloaded image 22760
# Downloaded image 16555
# Downloaded image 8976
# Downloaded image 7102
# Downloaded image 34605
# Downloaded image 50340
# Downloaded image 55400
# Downloaded image 3790
# Downloaded image 8378
# Downloaded image 30097
# Downloaded image 2642
# Downloaded image 43565
# Downloaded image 28854
# Downloaded image 13215
# Downloaded image 27020
# Downloaded image 46017
# Downloaded image 7330
# Downloaded image 49863
# Downloaded image 16767
# Downloaded image 31979
# Downloaded image 50172
# Downloaded image 28068
# Downloaded image 23480
# Downloaded image 44740
# Downloaded image 5467
# Downloaded image 20205
# Downloaded image 14030
# Downloaded image 36360
# Downloaded image 45692
# Downloaded image 57357
# Downloaded image 10490
# Downloaded image 33612
# Downloaded image 39328
# Downloaded image 41232
# Downloaded image 11542
# Downloaded image 56285
# Downloaded image 25777
# Downloaded image 2226
# Downloaded image 43101
# Downloaded image 18299
# Downloaded image 13671
# Downloaded image 27444
# Downloaded image 26596
# Downloaded image 55064
# Downloaded image 50516
# Downloaded image 6686
# Downloaded image 34053
# Downloaded image 46473
# Downloaded image 7754
# Downloaded image 55858
# Downloaded image 35181
# Downloaded image 22136
# Downloaded image 16303
# Downloaded image 15586
# Downloaded image 36704
# Downloaded image 5003
# Downloaded image 14454
# Downloaded image 53393
# Downloaded image 11126
# Downloaded image 25313
# Downloaded image 57733
# Downloaded image 40784
# Downloaded image 36536
# Downloaded image 52073
# Downloaded image 58549
# Downloaded image 14666
# Downloaded image 33878
# Downloaded image 44116
# Downloaded image 5231
# Downloaded image 25121
# Downloaded image 32196
# Downloaded image 33044
# Downloaded image 57501
# Downloaded image 54384
# Downloaded image 13443
# Downloaded image 2014
# Downloaded image 43333
# Downloaded image 49609
# Downloaded image 31713
# Downloaded image 12591
# Downloaded image 55256
# Downloaded image 18897
# Downloaded image 34261
# Downloaded image 50724
# Downloaded image 2828
# Downloaded image 22304
# Downloaded image 16131
# Downloaded image 46641
# Downloaded image 7566
# Downloaded image 19945
# Downloaded image 13685
# Downloaded image 54142
# Downloaded image 26562
# Downloaded image 55090
# Failed to download image 12757: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Downloaded image 42027
# Downloaded image 3300
# Downloaded image 17225
# Downloaded image 6672
# Downloaded image 47555
# Downloaded image 46487
# Downloaded image 51430
# Downloaded image 15572
# Downloaded image 21747
# Downloaded image 4125
# Downloaded image 45202
# Downloaded image 37622
# Downloaded image 20695
# Downloaded image 53367
# Downloaded image 32350
# Downloaded image 56615
# Downloaded image 4919
# Downloaded image 10000
# Downloaded image 4317
# Downloaded image 45030
# Downloaded image 15740
# Downloaded image 52087
# Downloaded image 21575
# Downloaded image 37410
# Downloaded image 56427
# Downloaded image 32162
# Downloaded image 40542
# Downloaded image 38458
# Downloaded image 27682
# Downloaded image 9408
# Downloaded image 30635
# Downloaded image 42215
# Downloaded image 3132
# Downloaded image 34295
# Downloaded image 18863
# Downloaded image 6440
# Failed to download image 17017: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Downloaded image 23222
# Downloaded image 51602
# Downloaded image 7592
# Downloaded image 53531
# Downloaded image 44586
# Downloaded image 37074
# Downloaded image 4773
# Downloaded image 15324
# Downloaded image 21111
# Downloaded image 40126
# Downloaded image 24463
# Downloaded image 10656
# Downloaded image 37848
# Downloaded image 57191
# Downloaded image 56043
# Downloaded image 11784
# Downloaded image 32506
# Downloaded image 49299
# Downloaded image 42671
# Downloaded image 3556
# Downloaded image 26334
# Downloaded image 12101
# Downloaded image 54714
# Downloaded image 6818
# Downloaded image 2484
# Downloaded image 30251
# Downloaded image 22794
# Downloaded image 8982
# Downloaded image 51266
# Downloaded image 6024
# Downloaded image 47303
# Downloaded image 26106
# Downloaded image 12333
# Downloaded image 3764
# Downloaded image 30063
# Downloaded image 48179
# Downloaded image 54526
# Downloaded image 18609
# Downloaded image 35511
# Downloaded image 49897
# Downloaded image 16793
# Downloaded image 51054
# Downloaded image 50186
# Downloaded image 17641
# Downloaded image 23474
# Downloaded image 48945
# Downloaded image 6216
# Downloaded image 47131
# Downloaded image 37246
# Downloaded image 5493
# Downloaded image 15116
# Downloaded image 59239
# Downloaded image 21323
# Downloaded image 36394
# Downloaded image 4541
# Downloaded image 24651
# Downloaded image 10464
# Downloaded image 40314
# Downloaded image 56271
# Downloaded image 25783
# Downloaded image 27649
# Downloaded image 16932
# Downloaded image 49636
# Downloaded image 19146
# Downloaded image 55269
# Downloaded image 2817
# Downloaded image 7559
# Downloaded image 25922
# Downloaded image 36509
# Downloaded image 58576
# Downloaded image 14659
# Downloaded image 33847
# Downloaded image 39541
# Downloaded image 38493
# Downloaded image 40589
# Downloaded image 44915
# Downloaded image 59696
# Downloaded image 11925
# Downloaded image 58744
# Downloaded image 41669
# Downloaded image 39773
# Downloaded image 11119
# Downloaded image 5800
# Downloaded image 33249
# Downloaded image 2219
# Downloaded image 34850
# Downloaded image 54189
# Downloaded image 35982
# Downloaded image 8723
# Downloaded image 22935
# Downloaded image 28433
# Downloaded image 55867
# Downloaded image 22109
# Downloaded image 5458
# Downloaded image 58320
# Downloaded image 57368
# Downloaded image 14833
# Downloaded image 39317
# Downloaded image 25748
# Downloaded image 46814
# Downloaded image 49060
# Downloaded image 50971
# Downloaded image 16758
# Downloaded image 31946
# Downloaded image 28057
# Downloaded image 30894
# Downloaded image 34408
# Downloaded image 8175
# Downloaded image 7901
# Downloaded image 19522
# Downloaded image 13018
# Downloaded image 48380
# Downloaded image 43768
# Downloaded image 8949
# Downloaded image 13824
# Downloaded image 28265
# Downloaded image 58112
# Downloaded image 20008
# Downloaded image 57966
# Downloaded image 52428
# Downloaded image 37883
# Downloaded image 56088
# Downloaded image 39125
# Downloaded image 37279
# Downloaded image 15129
# Downloaded image 45659
# Downloaded image 38231
# Downloaded image 15915
# Downloaded image 11589
# Downloaded image 26139
# Downloaded image 51857
# Downloaded image 49094
# Downloaded image 48146
# Downloaded image 2689
# Downloaded image 9261
# Downloaded image 50985
# Downloaded image 54519
# Downloaded image 18636
# Downloaded image 26905
# Downloaded image 29171
# Downloaded image 22599
# Downloaded image 30860
# Downloaded image 6229
# Downloaded image 3569
# Downloaded image 8181
# Downloaded image 18404
# Downloaded image 6827
# Downloaded image 48374
# Downloaded image 9053
# Downloaded image 51259
# Downloaded image 29343
# Downloaded image 12902
# Downloaded image 28291
# Downloaded image 23679
# Downloaded image 40925
# Downloaded image 57992
# Downloaded image 36199
# Downloaded image 59034
# Downloaded image 38003
# Downloaded image 40119
# Downloaded image 10669
# Downloaded image 37877
# Downloaded image 21912
# Downloaded image 32539
# Downloaded image 48710
# Downloaded image 9437
# Downloaded image 17814
# Downloaded image 17028
# Downloaded image 3931
# Downloaded image 29727
# Downloaded image 35378
# Downloaded image 4328
# Downloaded image 20498
# Downloaded image 56418
# Downloaded image 52884
# Downloaded image 38467
# Downloaded image 21778
# Downloaded image 59662
# Downloaded image 10803
# Downloaded image 53358
# Downloaded image 4926
# Downloaded image 38655
# Downloaded image 48522
# Downloaded image 23813
# Downloaded image 9605
# Downloaded image 19380
# Downloaded image 12768
# Downloaded image 34098
# Downloaded image 54941
# Downloaded image 55893
# Downloaded image 42824
# Downloaded image 14462
# Downloaded image 36732
# Downloaded image 5809
# Downloaded image 57705
# Downloaded image 33240
# Downloaded image 32392
# Downloaded image 41660
# Downloaded image 11110
# Downloaded image 25325
# Downloaded image 55052
# Downloaded image 12795
# Downloaded image 2210
# Downloaded image 43137
# Downloaded image 34859
# Downloaded image 27472
# Failed to download image 22100: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Downloaded image 16335
# Downloaded image 50520
# Downloaded image 34065
# Downloaded image 47597
# Downloaded image 31725
# Downloaded image 8518
# Downloaded image 26792
# Downloaded image 55260
# Downloaded image 13475
# Downloaded image 27640
# Downloaded image 43305
# Downloaded image 22332
# Downloaded image 16107
# Downloaded image 46677
# Downloaded image 7550
# Downloaded image 19973
# Downloaded image 6482
# Downloaded image 34257
# Downloaded image 50712
# Downloaded image 28608
# Downloaded image 20465
# Downloaded image 14650
# Downloaded image 36500
# Downloaded image 15782
# Downloaded image 52045
# Downloaded image 40580
# Downloaded image 33072
# Downloaded image 25117
# Downloaded image 52879
# Downloaded image 41452
# Downloaded image 27224
# Downloaded image 30293
# Downloaded image 3594
# Downloaded image 7908
# Downloaded image 34633
# Downloaded image 50376
# Downloaded image 9892
# Downloaded image 23684
# Downloaded image 22756
# Downloaded image 8940
# Downloaded image 7134
# Downloaded image 36164
# Downloaded image 39910
# Downloaded image 52421
# Downloaded image 20001
# Downloaded image 44544
# Downloaded image 56081
# Downloaded image 11746
# Downloaded image 25573
# Downloaded image 41036
# Downloaded image 33416
# Downloaded image 10694
# Downloaded image 57153
# Downloaded image 4583
# Downloaded image 36356
# Downloaded image 44776
# Downloaded image 5451
# Downloaded image 37284
# Downloaded image 20233
# Downloaded image 58329
# Downloaded image 14006
# Downloaded image 11574
# Downloaded image 25741
# Downloaded image 24693
# Downloaded image 57361
# Downloaded image 33624
# Downloaded image 50978
# Downloaded image 2674
# Downloaded image 43553
# Downloaded image 13223
# Downloaded image 27016
# Downloaded image 19719
# Downloaded image 55436
# Downloaded image 49069
# Downloaded image 31173
# Downloaded image 17683
# Downloaded image 34401
# Downloaded image 46021
# Downloaded image 7306
# Downloaded image 49855
# Downloaded image 22564
# Downloaded image 16751
# Downloaded image 54722
# Downloaded image 30267
# Downloaded image 43795
# Downloaded image 42647
# Downloaded image 8188
# Downloaded image 3560
# Downloaded image 12137
# Downloaded image 6012
# Downloaded image 47335
# Downloaded image 9866
# Downloaded image 17445
# Downloaded image 50382
# Downloaded image 23670
# Downloaded image 28298
# Downloaded image 56849
# Downloaded image 4745
# Downloaded image 15312
# Downloaded image 21127
# Downloaded image 38836
# Downloaded image 53507
# Downloaded image 5697
# Downloaded image 56075
# Downloaded image 25587
# Downloaded image 32530
# Downloaded image 40110
# Downloaded image 24455
# Downloaded image 10660
# Downloaded image 15120
# Downloaded image 21315
# Downloaded image 4577
# Downloaded image 45650
# Downloaded image 44782
# Downloaded image 53735
# Downloaded image 11580
# Downloaded image 56247
# Downloaded image 57395
# Downloaded image 10452
# Downloaded image 40322
# Downloaded image 38238
# Downloaded image 9268
# Downloaded image 2680
# Downloaded image 30055
# Downloaded image 28896
# Downloaded image 54510
# Downloaded image 12305
# Downloaded image 29944
# Downloaded image 3752
# Downloaded image 31187
# Downloaded image 17677
# Downloaded image 30869
# Downloaded image 23442
# Downloaded image 6220
# Downloaded image 22590
# Downloaded image 29178
# Downloaded image 14496
# Downloaded image 15544
# Downloaded image 4113
# Downloaded image 45234
# Downloaded image 40746
# Downloaded image 32366
# Downloaded image 41694
# Downloaded image 26554
# Downloaded image 19389
# Downloaded image 42011
# Downloaded image 3336
# Downloaded image 54174
# Downloaded image 27486
# Downloaded image 35143
# Downloaded image 7796
# Downloaded image 51406
# Downloaded image 17213
# Downloaded image 34091
# Downloaded image 54948
# Downloaded image 6644
# Downloaded image 47563
# Downloaded image 42223
# Downloaded image 3104
# Downloaded image 55294
# Downloaded image 54346
# Downloaded image 13481
# Downloaded image 30603
# Downloaded image 3938
# Downloaded image 51634
# Downloaded image 46683
# Downloaded image 19987
# Downloaded image 18855
# Downloaded image 6476
# Downloaded image 17021
# Downloaded image 23214
# Downloaded image 20491
# Downloaded image 4321
# Downloaded image 45006
# Downloaded image 15776
# Downloaded image 59459
# Downloaded image 21543
# Downloaded image 40574
# Downloaded image 1653
# Downloaded image 33086
# Downloaded image 10204
# Downloaded image 56411
# Downloaded image 48184
# Downloaded image 50947
# Downloaded image 27029
# Downloaded image 19726
# Downloaded image 55409
# Downloaded image 46822
# Downloaded image 51895
# Downloaded image 8371
# Downloaded image 3799
# Downloaded image 49056
# Downloaded image 23489
# Downloaded image 28061
# Downloaded image 27815
# Downloaded image 31970
# Downloaded image 36369
# Downloaded image 44749
# Downloaded image 58316
# Downloaded image 14039
# Downloaded image 39321
# Downloaded image 10499
# Downloaded image 14805
# Downloaded image 56882
# Downloaded image 37089
# Downloaded image 57950
# Downloaded image 41009
# Downloaded image 39113
# Downloaded image 58918
# Downloaded image 33429
# Downloaded image 20802
# Downloaded image 9091
# Downloaded image 2479
# Downloaded image 8143
# Downloaded image 7937
# Downloaded image 19514
# Downloaded image 13812
# Downloaded image 28253
# Downloaded image 50349
# Downloaded image 22769
# Downloaded image 33871
# Downloaded image 58540
# Downloaded image 5238
# Downloaded image 25914
# Downloaded image 21588
# Downloaded image 53994
# Downloaded image 57508
# Downloaded image 44923
# Downloaded image 25128
# Downloaded image 52846
# Downloaded image 39577
# Downloaded image 8527
# Downloaded image 49600
# Downloaded image 12598
# Downloaded image 19170
# Downloaded image 16138
# Downloaded image 34268
# Downloaded image 28637
# Downloaded image 2821
# Downloaded image 19342
# Downloaded image 13678
# Downloaded image 18290
# Downloaded image 55851
# Downloaded image 35188
# Downloaded image 43934
# Downloaded image 28405
# Downloaded image 54983
# Downloaded image 20668
# Downloaded image 11913
# Downloaded image 5836
# Downloaded image 39745
# Downloaded image 33885
# Downloaded image 37419
# Downloaded image 24832
# Downloaded image 45039
# Downloaded image 15749
# Downloaded image 59466
# Downloaded image 38451
# Downloaded image 39583
# Downloaded image 19184
# Downloaded image 18056
# Downloaded image 48726
# Downloaded image 9401
# Downloaded image 17822
# Downloaded image 3907
# Downloaded image 29711
# Downloaded image 6449
# Downloaded image 55099
# Downloaded image 35940
# Downloaded image 3309
# Downloaded image 23825
# Downloaded image 48514
# Downloaded image 9633
# Downloaded image 34892
# Downloaded image 51439
# Downloaded image 42812
# Downloaded image 29523
# Downloaded image 54977
# Downloaded image 10835
# Downloaded image 59654
# Downloaded image 10009
# Downloaded image 38663
# Downloaded image 40779
# Downloaded image 32359
# Downloaded image 4910
# Downloaded image 43598
# Downloaded image 48170
# Downloaded image 9257
# Downloaded image 18600
# Downloaded image 8385
# Downloaded image 28095
# Downloaded image 17648
# Downloaded image 30856
# Downloaded image 47138
# Downloaded image 26933
# Downloaded image 31984
# Downloaded image 29147
# Downloaded image 59230
# Downloaded image 4548
# Downloaded image 1806
# Downloaded image 15923
# Downloaded image 56278
# Downloaded image 24658
# Downloaded image 38207
# Downloaded image 56876
# Downloaded image 21118
# Downloaded image 59002
# Downloaded image 53538
# Downloaded image 36993
# Downloaded image 21924
# Downloaded image 38035
# Downloaded image 57198
# Downloaded image 18432
# Downloaded image 6811
# Downloaded image 48342
# Downloaded image 9065
# Downloaded image 30258
# Downloaded image 42678
# Downloaded image 49290
# Downloaded image 12108
# Downloaded image 9859
# Downloaded image 12934
# Downloaded image 55293
# Downloaded image 3103
# Downloaded image 42224
# Downloaded image 9439
# Downloaded image 30604
# Downloaded image 54341
# Downloaded image 13486
# Downloaded image 19980
# Downloaded image 46684
# Downloaded image 51633
# Downloaded image 29729
# Downloaded image 23213
# Downloaded image 17026
# Downloaded image 18852
# Downloaded image 6471
# Downloaded image 37421
# Downloaded image 20496
# Downloaded image 21544
# Downloaded image 15771
# Downloaded image 45001
# Downloaded image 4326
# Downloaded image 10203
# Downloaded image 24036
# Downloaded image 1654
# Downloaded image 38469
# Downloaded image 33081
# Downloaded image 40573
# Downloaded image 56416
# Downloaded image 14491
# Downloaded image 37613
# Downloaded image 45233
# Downloaded image 4114
# Downloaded image 15543
# Downloaded image 40741
# Downloaded image 10031
# Downloaded image 24204
# Downloaded image 56624
# Downloaded image 4928
# Downloaded image 41693
# Downloaded image 32361
# Downloaded image 42016
# Downloaded image 12766
# Downloaded image 26553
# Downloaded image 27481
# Downloaded image 54173
# Downloaded image 51401
# Downloaded image 35144
# Downloaded image 7791
# Downloaded image 47564
# Downloaded image 34096
# Downloaded image 6643
# Downloaded image 17214
# Downloaded image 45657
# Downloaded image 4570
# Downloaded image 21312
# Downloaded image 15127
# Downloaded image 53732
# Downloaded image 44785
# Downloaded image 11587
# Downloaded image 56240
# Downloaded image 40325
# Downloaded image 57392
# Downloaded image 10455
# Downloaded image 24660
# Downloaded image 54517
# Downloaded image 18638
# Downloaded image 28891
# Downloaded image 48148
# Downloaded image 2687
# Downloaded image 30052
# Downloaded image 3755
# Downloaded image 31180
# Downloaded image 29943
# Downloaded image 47100
# Downloaded image 6227
# Downloaded image 17670
# Downloaded image 22597
# Downloaded image 43792
# Downloaded image 30260
# Downloaded image 54725
# Downloaded image 6829
# Downloaded image 12130
# Downloaded image 26305
# Downloaded image 3567
# Downloaded image 42640
# Downloaded image 23677
# Downloaded image 17442
# Downloaded image 50385
# Downloaded image 47332
# Downloaded image 6015
# Downloaded image 35712
# Downloaded image 51257
# Downloaded image 21120
# Downloaded image 15315
# Downloaded image 4742
# Downloaded image 5690
# Downloaded image 32537
# Downloaded image 56072
# Downloaded image 37879
# Downloaded image 24452
# Downloaded image 4584
# Downloaded image 36351
# Downloaded image 14001
# Downloaded image 20234
# Downloaded image 5456
# Downloaded image 37283
# Downloaded image 44771
# Downloaded image 25746
# Downloaded image 11573
# Downloaded image 39319
# Downloaded image 33623
# Downloaded image 57366
# Downloaded image 24694
# Downloaded image 27011
# Downloaded image 13224
# Downloaded image 43554
# Downloaded image 28865
# Downloaded image 2673
# Downloaded image 31174
# Downloaded image 8349
# Downloaded image 55431
# Downloaded image 34406
# Downloaded image 28059
# Downloaded image 48980
# Downloaded image 17684
# Downloaded image 31948
# Downloaded image 51091
# Downloaded image 22563
# Downloaded image 7301
# Downloaded image 46026
# Downloaded image 30294
# Downloaded image 27223
# Downloaded image 13016
# Downloaded image 3593
# Downloaded image 34634
# Downloaded image 7133
# Downloaded image 8947
# Downloaded image 22751
# Downloaded image 52426
# Downloaded image 39917
# Downloaded image 5664
# Downloaded image 57968
# Downloaded image 20006
# Downloaded image 41031
# Downloaded image 25574
# Downloaded image 56086
# Downloaded image 11741
# Downloaded image 10693
# Downloaded image 57154
# Downloaded image 58920
# Downloaded image 19148
# Downloaded image 55267
# Downloaded image 26795
# Downloaded image 31722
# Downloaded image 49638
# Downloaded image 43302
# Downloaded image 2025
# Downloaded image 13472
# Downloaded image 7557
# Downloaded image 35382
# Downloaded image 19974
# Downloaded image 16100
# Downloaded image 50715
# Downloaded image 6485
# Downloaded image 34250
# Downloaded image 44127
# Downloaded image 14657
# Downloaded image 33849
# Downloaded image 20462
# Downloaded image 15785
# Downloaded image 52042
# Downloaded image 36507
# Downloaded image 57530
# Downloaded image 33075
# Downloaded image 40587
# Downloaded image 41455
# Downloaded image 25110
# Downloaded image 44315
# Downloaded image 36735
# Downloaded image 21782
# Downloaded image 59698
# Downloaded image 33247
# Downloaded image 57702
# Downloaded image 25322
# Downloaded image 11117
# Downloaded image 41667
# Downloaded image 32395
# Downloaded image 55055
# Downloaded image 12792
# Downloaded image 27475
# Downloaded image 13640
# Downloaded image 54187
# Downloaded image 43130
# Downloaded image 2217
# Downloaded image 16332
# Downloaded image 55869
# Downloaded image 46442
# Downloaded image 47590
# Downloaded image 34062
# Downloaded image 50527
# Downloaded image 59005
# Downloaded image 56871
# Downloaded image 44588
# Downloaded image 32508
# Downloaded image 59839
# Downloaded image 21923
# Downloaded image 36994
# Downloaded image 10658
# Downloaded image 40128
# Downloaded image 38032
# Downloaded image 9062
# Downloaded image 48345
# Downloaded image 18435
# Downloaded image 6816
# Downloaded image 3558
# Downloaded image 23648
# Downloaded image 12933
# Downloaded image 54528
# Downloaded image 18607
# Downloaded image 9250
# Downloaded image 48177
# Downloaded image 8382
# Downloaded image 50188
# Downloaded image 30851
# Downloaded image 28092
# Downloaded image 49899
# Downloaded image 29140
# Downloaded image 31983
# Downloaded image 26934
# Downloaded image 45668
# Downloaded image 15118
# Downloaded image 59237
# Downloaded image 1801
# Downloaded image 37248
# Downloaded image 15924
# Downloaded image 38200
# Downloaded image 42029
# Downloaded image 12759
# Downloaded image 35947
# Downloaded image 18263
# Downloaded image 9634
# Downloaded image 48513
# Downloaded image 23822
# Downloaded image 29524
# Downloaded image 42815
# Downloaded image 46489
# Downloaded image 54970
# Downloaded image 53369
# Downloaded image 10832
# Downloaded image 59653
# Downloaded image 38664
# Downloaded image 4917
# Downloaded image 24835
# Downloaded image 33882
# Downloaded image 59461
# Downloaded image 32950
# Downloaded image 52089
# Downloaded image 4319
# Downloaded image 38456
# Downloaded image 39584
# Downloaded image 56429
# Downloaded image 45802
# Downloaded image 19183
# Downloaded image 9406
# Downloaded image 17825
# Downloaded image 48721
# Downloaded image 18051
# Downloaded image 3900
# Downloaded image 17019
# Downloaded image 49435
# Downloaded image 8712
# Downloaded image 26598
# Downloaded image 19345
# Downloaded image 18297
# Downloaded image 34861
# Downloaded image 2228
# Downloaded image 22138
# Downloaded image 55856
# Downloaded image 6688
# Downloaded image 54984
# Downloaded image 50518
# Downloaded image 28402
# Downloaded image 43933
# Downloaded image 11914
# Downloaded image 15588
# Downloaded image 33278
# Downloaded image 5831
# Downloaded image 11128
# Downloaded image 39742
# Downloaded image 44118
# Downloaded image 58547
# Downloaded image 14668
# Downloaded image 33876
# Downloaded image 36538
# Downloaded image 25913
# Downloaded image 44924
# Downloaded image 39570
# Downloaded image 32198
# Downloaded image 52841
# Downloaded image 19177
# Downloaded image 55258
# Downloaded image 49607
# Downloaded image 16903
# Downloaded image 8520
# Downloaded image 27678
# Downloaded image 7568
# Downloaded image 2826
# Downloaded image 28630
# Downloaded image 18899
# Downloaded image 52419
# Downloaded image 41832
# Downloaded image 4789
# Downloaded image 56885
# Downloaded image 57957
# Downloaded image 20039
# Downloaded image 58123
# Downloaded image 24499
# Downloaded image 20805
# Downloaded image 9096
# Downloaded image 43759
# Downloaded image 7930
# Downloaded image 19513

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
class FashionKaggleDataset(Dataset):
    def __init__(self, df, image_dir=None, transform=None):
        self.df = df
        self.image_dir = image_dir
        self.transform = transform
        self.local_images = {}
        
        
        if image_dir:
            for filename in os.listdir(image_dir):
                if filename.endswith('.png') or filename.endswith('.jpg'):
                    try:
                        
                        img_id = int(filename.split('.')[0])
                        self.local_images[img_id] = os.path.join(image_dir, filename)
                    except:
                        continue

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_id = self.df.iloc[idx]['id']
        img_url = self.df.iloc[idx]['link']
        
        
        if self.image_dir and img_id in self.local_images:
            try:
                image = Image.open(self.local_images[img_id]).convert('RGB')
            except Exception as e:
                print(f"Failed to load local image {img_id}: {e}")
                image = Image.new('RGB', (64, 64), (0, 0, 0))  
        else:
            
            try:
                response = requests.get(img_url, timeout=5)
                image = Image.open(BytesIO(response.content)).convert('RGB')
            except Exception as e:
                print(f"Failed to load image from URL {img_url}: {e}")
                image = Image.new('RGB', (64, 64), (0, 0, 0))  
        
        if self.transform:
            image = self.transform(image)
        
        return image

# %%
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


image_dir = image_download_dir


dataset = FashionKaggleDataset(df, image_dir=image_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
class ConvVAE(nn.Module):
    def __init__(self, latent_dim=32):
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(128 * 8 * 8, 256),
            nn.ReLU(),
        )
        self.fc_mu = nn.Linear(256, latent_dim)
        self.fc_logvar = nn.Linear(256, latent_dim)

        # Decoder
        self.decoder_input = nn.Linear(latent_dim, 128 * 8 * 8)
        self.decoder = nn.Sequential(
            nn.Unflatten(1, (128, 8, 8)),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1),  
        )

    def encode(self, x):
        h = self.encoder(x)
        mu = self.fc_mu(h)
        logvar = self.fc_logvar(h)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        h = self.decoder_input(z)
        return self.decoder(h)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar

latent_dim = 32
vae = ConvVAE(latent_dim=latent_dim).to(device)

# %%
def vae_loss(recon_x, x, mu, logvar, beta=1.0):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + beta * kl_loss

# %%
optimizer = optim.Adam(vae.parameters(), lr=1e-3)

num_epochs = 10
vae.train()
for epoch in range(num_epochs):
    total_loss = 0
    for batch_idx, data in enumerate(dataloader):
        data = data.to(device)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar = vae(data)
        loss = vae_loss(recon_batch, data, mu, logvar)
        
        loss.backward()
        total_loss += loss.item()
        optimizer.step()
        
        if batch_idx % 100 == 0:
            print(f'Epoch {epoch+1}/{num_epochs}, Batch {batch_idx}/{len(dataloader)}, Loss: {loss.item()/len(data):.4f}')
    
    print(f'Epoch {epoch+1}/{num_epochs}, Average Loss: {total_loss/len(dataloader.dataset):.4f}')


torch.save(vae.state_dict(), os.path.join(base_path, "vae_fashion.pth"))

# %%
def visualize_vae_results(vae, dataloader, num_samples=8):
    vae.eval()
    with torch.no_grad():
        data = next(iter(dataloader)).to(device)
        recon, _, _ = vae(data)
        
        data = data * 0.5 + 0.5
        recon = recon * 0.5 + 0.5
        
        plt.figure(figsize=(15, 4))
        for i in range(num_samples):
            plt.subplot(2, num_samples, i+1)
            plt.imshow(data[i].permute(1, 2, 0).cpu().numpy())
            plt.axis('off')
            if i == 0:
                plt.title('Real Images')
            
            plt.subplot(2, num_samples, num_samples+i+1)
            plt.imshow(recon[i].permute(1, 2, 0).cpu().numpy())
            plt.axis('off')
            if i == 0:
                plt.title('Reconstructed Images')
        plt.show()
        
        z = torch.randn(num_samples, latent_dim).to(device)
        samples = vae.decode(z)
        samples = samples * 0.5 + 0.5
        
        plt.figure(figsize=(15, 2))
        for i in range(num_samples):
            plt.subplot(1, num_samples, i+1)
            plt.imshow(samples[i].permute(1, 2, 0).cpu().numpy())
            plt.axis('off')
            if i == 0:
                plt.title('Generated Samples')
        plt.show()

visualize_vae_results(vae, dataloader)

# %%
primary_colors = {
    "red": [(200, 0, 0), (255, 100, 100)],
    "green": [(0, 200, 0), (100, 255, 100)],
    "blue": [(0, 0, 200), (100, 100, 255)],
    "yellow": [(200, 200, 0), (255, 255, 205)],
    "light yellow": [(200, 236, 205), (255, 255, 255)],
    "black": [(0, 0, 0), (50, 50, 50)],
    "white": [(200, 200, 200), (255, 255, 255)],
    "grey": [(100, 100, 100), (200, 200, 200)],
    "purple": [(100, 0, 100), (200, 100, 200)],
    "orange": [(200, 100, 0), (255, 150, 50)],
    "light red": [(200, 100, 100), (255, 180, 180)],
    "dark red": [(100, 0, 0), (200, 100, 100)],
    "light green": [(100, 255, 100), (150, 255, 150)],
    "dark green": [(0, 100, 0), (100, 200, 100)],
    "light blue": [(100, 100, 255), (150, 150, 255)],
    "dark blue": [(0, 0, 100), (100, 100, 200)],
    "light grey": [(150, 150, 150), (200, 200, 200)],
    "dark grey": [(50, 50, 50), (100, 100, 100)],
}

# %%
def is_color_in_range(color, color_range):
    return all(
        lower <= c <= upper
        for c, (lower, upper) in zip(color, zip(color_range[0], color_range[1]))
    )

def get_primary_color_name(detected_color):
    for color_name, color_range in primary_colors.items():
        if is_color_in_range(detected_color, color_range):
            return color_name
    return "Multi"

# %%
def grid_sample(image, grid_size=15):
    width, height = image.size
    pixels = image.load()
    sampled_pixels = []
    for x in range(0, width, width // grid_size):
        for y in range(0, height, height // grid_size):
            r, g, b = pixels[x, y]
            if (r, g, b) != (0, 0, 0):
                sampled_pixels.append((r, g, b))
    return np.array(sampled_pixels)

def resize_image_from_center(image, scale_factor=1/3):
    original_width, original_height = image.size
    new_width = int(original_width * scale_factor)
    new_height = int(original_height * scale_factor)
    left = (original_width - new_width) // 2
    upper = (original_height - new_height) // 4
    right = left + new_width
    lower = upper + new_height
    cropped_image = image.crop((left, upper, right, lower))
    return cropped_image

# %%
def process_image_and_detect_colors(image):
    image = resize_image_from_center(image)
    grid_pixels = grid_sample(image, grid_size=15)
    if len(grid_pixels) > 0:
        color_counts = {}
        for pixel in grid_pixels:
            color_name = get_primary_color_name(tuple(pixel))
            if color_name in color_counts:
                color_counts[color_name] += 1
            else:
                color_counts[color_name] = 1
        primary_color_name = max(color_counts, key=color_counts.get)
        primary_color_value = tuple(grid_pixels[color_counts[primary_color_name] - 1])
        return primary_color_name, primary_color_value
    return "Unknown", (0, 0, 0)

# %%
def detect_color_from_file(row, image_dir):
    img_id = row['id']
    img_url = row['link']
    img_path = os.path.join(image_dir, f"{img_id}.jpg")
    
   
    if os.path.exists(img_path):
        try:
            image = Image.open(img_path).convert('RGB')
            color_name, color_rgb = process_image_and_detect_colors(image)
            return pd.Series([color_name, color_rgb])
        except Exception as e:
            print(f"Failed to process local image {img_id}: {e}")
    
    
    try:
        response = requests.get(img_url, timeout=5)
        image = Image.open(BytesIO(response.content)).convert('RGB')
        color_name, color_rgb = process_image_and_detect_colors(image)
        return pd.Series([color_name, color_rgb])
    except Exception as e:
        print(f"Failed to process {img_url}: {e}")
        return pd.Series(["Unknown", (0, 0, 0)])

# %%
from tqdm import tqdm
tqdm.pandas()
df[['detected_color_name', 'detected_color_rgb']] = df.progress_apply(
    lambda row: detect_color_from_file(row, image_download_dir), axis=1
)


df.to_csv(os.path.join(base_path, "fashion_with_colors.csv"), index=False)

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
def analyze_latent_space(vae, dataloader, df, num_samples=1000):
    vae.eval()
    latent_vectors = []
    colors = []
    
    with torch.no_grad():
        for i, data in enumerate(dataloader):
            if i * dataloader.batch_size >= num_samples:
                break
            data = data.to(device)
            mu, _ = vae.encode(data)
            latent_vectors.append(mu.cpu().numpy())
            
            batch_indices = range(i * dataloader.batch_size, min((i+1) * dataloader.batch_size, len(df)))
            batch_colors = df.iloc[batch_indices]['detected_color_name'].tolist()
            colors.extend(batch_colors)
    
    latent_vectors = np.concatenate(latent_vectors, axis=0)
    
    pca = PCA(n_components=2)
    latent_2d = pca.fit_transform(latent_vectors)
    
    plt.figure(figsize=(10, 8))
    for color in set(colors):
        if color and color != "Unknown":
            mask = np.array(colors) == color
            plt.scatter(latent_2d[mask, 0], latent_2d[mask, 1], label=color, alpha=0.6)
    plt.legend()
    plt.title('Latent Space Colored by Detected Color')
    plt.show()

analyze_latent_space(vae, dataloader, df)

# %%
df_subset = df.head(1000)  
dataset = FashionKaggleDataset(df_subset, image_dir=image_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=0)

# %%
df_subset = df[df['articleType'].isin(['Tshirts', 'Jeans'])].head(1000)
dataset = FashionKaggleDataset(df_subset, image_dir=image_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=0)
